# %%
a,b = 13, 6
c = a+b
print("SUM: ", c)
# Out:
# SUM:  19

# %%
a**b
# Out:
# 4826809

# %%
a/b
# Out:
# 2.1666666666666665

# %%
a//b
# Out:
# 2

# %%
a%b
# Out:
# 1

# %%
a**-1
# Out:
# 0.07692307692307693

# %%
10**-1
# Out:
# 0.1

# %%
2**-1
# Out:
# 0.5

# %%
7**0
# Out:
# 1

# %%
7%2
# Out:
# 1

# %%
m,n = 3,2

# %%
m<n, m>n, m<=n, m>=n, m==n
# Out:
# (False, True, False, True, False)

# %%
# Assignment operator

# %%
x = 100
x+=2
x
# Out:
# 102

# %%
x = 100
x-=29
x
# Out:
# 71

# %%
x = 100
x*=2
x
# Out:
# 200

# %%
x**=2
x
# Out:
# 22500

# %%
x = 100
x/=2
x
# Out:
# 50.0

# %%
x = 100
x//=3
x
# Out:
# 33

# %%
x = 100
x**=2
x
# Out:
# 10000

# %%
a,b = 2,10
a<5 and b>9, a<5 or b>9
# Out:
# (True, True)

# %%
a<5 or b>19, a<5 and b>19
# Out:
# (True, False)

# %%
is_allounce = True
not is_allounce
# Out:
# False
